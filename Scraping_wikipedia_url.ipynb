# %%
import requests
from bs4 import BeautifulSoup
import random

def scrapeWikiArticle(url):
    response = requests.get(url=url,)
    soup = BeautifulSoup(response.content, 'html.parser')
    title = soup.find(id="firstHeading")
    print(title.text)
    allLinks = soup.find(id="bodyContent").find_all("a")
    random.shuffle(allLinks)
    linkToScrape = 0

    for link in allLinks:
        # We are only interested in other wiki articles
        if link['href'].find("/wiki/") == -1: 
            continue
        # Use this link to scrap
        linkToScrape = link
        break

    scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])

scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
# Out:
# Star
# Fakhr al-Din al-Razi
# Universe
# Quantum
# Quantum cellular automaton
# Paul Douglas Tougaw
# Category:Valparaiso University faculty
# Gilbert Meilaender
# Oxford University Press
# File:Coat of arms of the University of Oxford.svg
# Oxford University Press
# The Oxford History of South Africa
# Oxford University Press
# Mumbai
# Don Bosco High School, Matunga
# Anant Mahadevan
# Indian people
# Indian cuisine
# Gujarati cuisine
# Anglo-Indian cuisine
# Turks and Caicos Islands
# Washington Misick
# Michael Misick
# Member of parliament
# Althing
# Portal:Iceland
# Icelandic art
# Cubism
# Historicism (art)
# New European Painting
# Expressionism
# Thomas Pynchon
# Category:Writers from Glen Cove, New York
# Margalit Fox
# John Gardner (British writer)
# Win, Lose or Die
# Mikhail Gorbachev
# Central Committee elected by the 23rd Congress of the Communist Party of the Soviet Union
# 9th Politburo, the 9th Secretariat and the 9th Orgburo of the Russian Communist Party (Bolsheviks)
# Nikolai Bukharin
# Communism
# Template:More citations needed section
# Template:Partisan sources
# Template:Format footnotes
# Wikipedia:Citing sources
# Wikipedia:Shortcut
# Wikipedia:Categorization
# Wikipedia:Citing sources
# Template:Unreferenced
# Template:Unreferenced section
# Template:Page numbers improve
# Template:Page numbers improve
# Template:Original research section
# Template:Primary sources
# Template:Primary sources/doc
# Wikipedia:Identifying and using primary sources
# Wikipedia:Project namespace
# Wikipedia:Meta
# Wikipedia:Administrators' guide/Blocking/Tools
# Wikipedia:Huggle
# Help:Lua
# Wikipedia:WikiProject Accessibility/Navigation menu
# Wikipedia:WikiProject Accessibility/Resources and references
# Wikipedia:WikiProject Accessibility/Manual of Style draft
# Wikipedia:WikiProject Accessibility/Policy proposal
# Wikipedia:WikiProject Accessibility/Top priority issues with templates
# Wikipedia:WikiProject Accessibility/Policy proposal
# Wikipedia:WikiProject Accessibility/Popular pages
# Digital Accessible Information System
# Wayback Machine
# Copyright
# Plant breeders' rights
# United States
# Robert Nozick
# Federalism
# World Federalist Movement
# Democratic World Federalists
# Portal:World
# Papua New Guinea
# Economy of Poland
# Euro
# Google Finance
# Google Science Fair
# LevelDB
# Android (operating system)
# Vivo NEX
# Oppo A9 2020
# Oppo phones
# Oppo phones
# Category:Android (operating system) devices
# HTC Jetstream
# Google Nexus
# Endoxon
# Google Translate
# Megabyte
# Gibibit
# Template talk:Quantities of bits
# Computer
# Harvard Mark I
# Charles Babbage
# Augustus De Morgan
# Ratio test
# Limit of a sequence
# Ákos Császár
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# D:\anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# D:\anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# D:\anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# D:\anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000021434832D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# D:\anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='en.wikipedia.orghttps', port=443): Max retries exceeded with url: //www.wikidata.org/wiki/Q523012 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000021434832D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in <module>
#      22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
# ---> 24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#      20         break
#      21
# ---> 22     scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      23
#      24 scrapeWikiArticle("https://en.wikipedia.org/wiki/Star")
#
# C:\Users\JASMEE~1\AppData\Local\Temp/ipykernel_4336/1960291892.py in scrapeWikiArticle(url)
#       4
#       5 def scrapeWikiArticle(url):
# ----> 6     response = requests.get(url=url,)
#       7     soup = BeautifulSoup(response.content, 'html.parser')
#       8     title = soup.find(id="firstHeading")
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='en.wikipedia.orghttps', port=443): Max retries exceeded with url: //www.wikidata.org/wiki/Q523012 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000021434832D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
